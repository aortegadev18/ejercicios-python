# %% [markdown]
# Ejercicio 1...
# Escribir un programa que muestre por pantalla la cadena ¡Hola Mundo!.

# %%
print("Hello, World!")
# Out:
# Hello, World!

# %% [markdown]
# Ejercicio 2...
# Escribir un programa que almacene la cadena ¡Hola Mundo! en una variable y luego muestre por pantalla el contenido de la variable.

# %%
v1 = "Hello, World!"

print(v1)
# Out:
# Hello, World!

# %% [markdown]
# Ejercicio 3...
# Escribir un programa que pregunte el nombre del usuario en la consola y después de que el usuario lo introduzca muestre por pantalla la cadena ¡Hola nombre!, donde nombre es el nombre que el usuario haya introducido.

# %%
nombre = input("Ingrese su nombre: ")
print(f"Hola, {nombre}!")
# Out:
# Hola, Andresito!

# %% [markdown]
# Ejercicio 4...
# Escribir un programa que muestre por pantalla el resultado de la siguiente operación aritmética
#  (3+2/2*5)**2

# %%
formula= ((3+2)/(2*5))**2

print(f"El resultado de la formula es: {formula}")
# Out:
# El resultado de la formula es: 0.25

# %% [markdown]
# Ejercicio 5...
# Escribir un programa que pregunte al usuario por el número de horas trabajadas y el coste por hora. Después debe mostrar por pantalla la paga que le corresponde.

# %%
htrabajadas = int(input("Ingrese horas trabajadas: "))
pagohora = float(input("Ingrese pago por hora: "))

salario = htrabajadas * pagohora

print (f"El salario que le corresponde es: {salario}")
# Out:
# El salario que le corresponde es: 35.0

# %% [markdown]
# Ejercicio 6...
# Escribir un programa que lea un entero positivo, n , introducido por el usuario y después muestre en pantalla la suma de todos los enteros desde 1 hasta n.
#  La suma de los primeros enteros positivos puede ser calculada de la siguiente forma:
#
#  suma = n(n+1)/(2)

# %%
n = int(input("Ingrese un número: "))
suma = n * (n + 1) / 2
print(f"La suma de los primeros {n} números naturales es: {suma}")
# Out:
# La suma de los primeros 10 números naturales es: 55.0

# %% [markdown]
# Ejercicio 7...
# Escribir un programa que pida al usuario su peso (en kg) y estatura (en metros), calcule el índice de masa corporal y lo almacene en una variable, y muestre por pantalla la frase Tu índice de masa corporal es imc donde imc es el índice de masa corporal calculado redondeado con dos decimales.

# %%
peso = float(input("Ingrese su peso en kilogramos: "))
estatura = float(input("Ingrese su estatura en metros: "))

imc = peso / (estatura ** 2)

imc = round(imc, 2)

print(f"Tu indice de masa corporal es: {imc}")
# Out:
# Tu indice de masa corporal es: 21.26

# %% [markdown]
# Ejercicio 8...
# Escribir un programa que pida al usuario dos números enteros y muestre por pantalla la <n> entre <m> da un cociente <c> y un resto <r> donde <n> y <m> son los números introducidos por el usuario, y <c> y <r> son el cociente y el resto de la división entera respectivamente.

# %%
dividendo = int(input("Ingrese otro número: "))
divisor = int(input("Ingrese un número: "))


cociente = dividendo / divisor
resto = (cociente * divisor) - dividendo

print(f"n: {dividendo} dividido para m: {divisor} , nos da un cociente de: {cociente} ,  y un resto igual  a: {resto}")
# Out:
# n: 30 dividido para m: 20 , nos da un cociente de: 1.5 ,  y un resto igual  a: 0.0

# %% [markdown]
# Ejercicio 9...
# Escribir un programa que pregunte al usuario una cantidad a invertir, el interés anual y el número de años, y muestre por pantalla el capital obtenido en la inversión.

# %%
cantidad = int(input("Ingresa la cantidad que quieres invertir: "))
interes = float(input("Ingresa el interes anual en porcentaje:"))
tiempo = int(input("Ingresa el tiempo en años: "))

capital_Obtenido = cantidad * (1 + interes * tiempo)

print(f"El capital que haz obtenido despues de {tiempo} años es: {capital_Obtenido}")
# Out:
# El capital que haz obtenido despues de 2 años es: 21000.0

# %% [markdown]
# Ejercicio 10...
# Una juguetería tiene mucho éxito en dos de sus productos: payasos y muñecas. Suele hacer venta por correo y la empresa de logística les cobra por peso de cada paquete así que deben calcular el peso de los payasos y muñecas que saldrán en cada paquete a demanda. Cada payaso pesa 112 g y cada muñeca 75 g. Escribir un programa que lea el número de payasos y muñecas vendidos en el último pedido y calcule el peso total del paquete que será enviado.

# %%
payasos = int(input("Ingrese la cantidad de payasos: "))
muñecas = int(input("Ingrese la cantidad de muñecas: "))

peso_total = (payasos * 112) + (muñecas * 75)
print(f"El peso total de su pedido es de {peso_total} gramos")
# Out:
# El peso total de su pedido es de 2990 gramos

# %% [markdown]
# Ejercicio 11...
# Imagina que acabas de abrir una nueva cuenta de ahorros que te ofrece el 4% de interés al año. Estos ahorros debido a intereses, que no se cobran hasta finales de año, se te añaden al balance final de tu cuenta de ahorros. Escribir un programa que comience leyendo la cantidad de dinero depositada en la cuenta de ahorros, introducida por el usuario. Después el programa debe calcular y mostrar por pantalla la cantidad de ahorros tras el primer, segundo y tercer años. Redondear cada cantidad a dos decimales.

# %%
ahorros = float(input("Ingrese la cantidad de dinero que tiene ahorrada: "))

ahorros_año1 = ahorros * (1 + 0.04 * 1)
ahorros_año2 = ahorros * (1 + 0.04 * 2)
ahorros_año3 = ahorros * (1 + 0.04 * 3)

print(f"El dinero que tendrá después de 1 año es: {ahorros_año1}")
print(f"El dinero que tendrá después de 2 años es: {ahorros_año2}")
print(f"El dinero que tendrá después de 3 años es: {ahorros_año3}")

print(f"Recuerda revisar tu dinero siempre :)")
# Out:
# El dinero que tendrá después de 1 año es: 1040.0
# El dinero que tendrá después de 2 años es: 1080.0
# El dinero que tendrá después de 3 años es: 1120.0
# Recuerda revisar tu dinero siempre :)

# %% [markdown]
# Ejercicio 12
# Una panadería vende barras de pan a 3.49€ cada una. El pan que no es el día tiene un descuento del 60%. Escribir un programa que comience leyendo el número de barras vendidas que no son del día. Después el programa debe mostrar el precio habitual de una barra de pan, el descuento que se le hace por no ser fresca y el coste final total.

# %%
barras_no_fresco = int(input("Ingrese la cantidad de barras de pan no fresco que han sido vendidas hoy: "))

precio_barra_fresco = 3.49

print (f"El precio del pan fresco es de {precio_barra_fresco} euros")

precio_final_no_freco = precio_barra_fresco * 60
costo_final = precio_final_no_freco / 100
costo_final = round(costo_final, 2)

print(f"El precio final de las barras de pan no fresco es de {costo_final} euros")

costo_final = barras_no_fresco * costo_final
costo_final = round(costo_final, 2)
print(f"El valor total vendido de las barras de pan no fresco es de {costo_final} euros")
# Out:
# El precio del pan fresco es de 3.49 euros
# El precio final de las barras de pan no fresco es de 2.09 euros
# El valor total vendido de las barras de pan no fresco es de 62.7 euros
